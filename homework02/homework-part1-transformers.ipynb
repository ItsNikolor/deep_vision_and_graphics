# %% [markdown]
# # Compact Convolutional Transformers
#
# This week we try to train Vision Transformer-like network for cifar10 images classification.
#
# This task is based on paper [Escaping the Big Data Paradigm with Compact Transformers](https://arxiv.org/pdf/2104.05704.pdf)

# %% [markdown]
# ## CIFAR dataset
#
# Dataset description:
#
# * 60k images of shape 3x32x32
# * 10 different classes: planes, dogs, cats, trucks, etc.
#
# <img src="imgs/cifar10.jpg" style="width:80%">

# %%
# when running in colab, un-comment this
# !wget https://raw.githubusercontent.com/yandexdataschool/Practical_DL/fall19/week03_convnets/cifar.py

# %%
#!L
import numpy as np
import random
from cifar import load_cifar10
X_train, y_train, X_val, y_val, X_test, y_test = load_cifar10("cifar_data")

class_names = np.array(['airplane', 'automobile', 'bird', 'cat', 'deer',
                        'dog', 'frog', 'horse', 'ship', 'truck'])

print(X_train.shape,y_train.shape)
# Out:
# Dataset not found. Downloading...
# (40000, 3, 32, 32) (40000,)

# %%
#!L
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=[12,10])
for i in range(12):
    plt.subplot(3,4,i+1)
    plt.imshow(np.transpose(X_train[i],[1,2,0]))
    plt.title(class_names[y_train[i]])

# %% [markdown]
# ## Prepare dataset and loss
#
# The following code is based on homework 1-pt1 and should be familiar to you.

# %%
#!L
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import transforms
import tqdm

# %%
#!L
def get_computing_device():
    if torch.cuda.is_available():
        device = torch.device('cuda:0')
    else:
        device = torch.device('cpu')
    return device

device = get_computing_device()
print(f"Our main computing device is '{device}'")
# Out:
# Our main computing device is 'cuda:0'

# %%
#!L
def compute_loss(logits, y_batch):
    return F.cross_entropy(logits, y_batch).mean().cpu()

# %%
from torchvision import transforms
means = np.array((0.4914, 0.4822, 0.4465))
stds = np.array((0.2470, 0.2435, 0.2616))

transform_augment = transforms.Compose([
    transforms.RandomResizedCrop((32,32), scale=(0.9, 1.0), ratio=(0.9, 1.1)),
    transforms.RandomRotation([-5, 5]),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.ColorJitter(0.2, 0.2, 0.2, 0.2),
    transforms.Normalize(means, stds),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(means, stds),
])

# %%
from torchvision.datasets import CIFAR10
train_loader = CIFAR10("./cifar_data/", train=True, transform=transform_augment)

train_batch_gen = torch.utils.data.DataLoader(train_loader, 
                                              batch_size=50,
                                              shuffle=True,
                                              num_workers=16)
val_loader = CIFAR10("./cifar_data/", train=False, transform=transform_test)

val_batch_gen = torch.utils.data.DataLoader(val_loader, 
                                              batch_size=50,
                                              shuffle=False,
                                              num_workers=16)

# %% [markdown]
# ## Task 1. Multi-head attention
#
# Your turn!

# %% [markdown]
# <img src="imgs/mha_img_original.png" style="width:50%">

# %% [markdown]
# Let's implement MultiHeadAttention for beggining. It's already implemented in pytorch, so we will use `nn.MultiHeadAttention` for testing of your implementation.
#
# As a reminder, (one-head) attention implements a simple formula: $\text{Attention}(Q,K,V) = \text{softmax}(\frac{QK^T}{\sqrt{d_k}})V$, where $d_k$ is size of K

# %%
from einops import rearrange


class CustomMultiHeadSelfAttention(nn.Module):
    def __init__(self, embed_dim, num_heads, dropout=0.0):
        super().__init__()
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.head_dim = embed_dim // num_heads
        assert embed_dim % num_heads == 0, "embed_dim must be divisible by num_heads"

        self.in_proj = nn.Linear(embed_dim, 3 * embed_dim)  # don't change the name
        self.out_proj = nn.Linear(embed_dim, embed_dim)  # don't change the name

        self.norm_coeff = self.head_dim**0.5

        self.attention_dropout = nn.Dropout(dropout)

    def forward(self, qkv):
        """
        qkv - query, key and value - it should be the same tensor since we implement self-attention
        """
        # YOUR CODE
        # 1. apply self.in_proj to qkv
        # 2. split the result of step 1 on three equal parts of size self.embed_dim: query, key, value
        # 3. compute scaled dot-product attention for different heads in loop.
        #    i-th head will work on query[:, :, i*head_dim: (i+1)*head_dim],
        #       key[:, :, i*head_dim: (i+1)*head_dim] and value[:, :, i*head_dim: (i+1)*head_dim]
        #    important: apply dropout to attention maps _after_ softmax, but _before_ multiplication by values.
        #    it follows original implementation and corresponds to dropping out tokens.
        # 4. concat all results
        # 5. apply self.out_proj to the result of step 5
        batch_size = qkv.shape[0]

        qkv = self.in_proj(qkv).reshape(batch_size, -1, 3, self.embed_dim)
        q, k, v = qkv[:, :, 0], qkv[:, :, 1], qkv[:, :, 2]

        q = q.reshape(batch_size, -1, self.num_heads, self.head_dim)
        k = k.reshape(batch_size, -1, self.num_heads, self.head_dim)
        v = v.reshape(batch_size, -1, self.num_heads, self.head_dim)

        q = rearrange(q, "b s h d -> (b h) s d")
        k = rearrange(k, "b s h d -> (b h) s d")
        v = rearrange(v, "b s h d -> (b h) s d")

        scale = q @ k.permute(0, 2, 1) / self.norm_coeff
        scale = scale.softmax(dim=-1)
        scale = self.attention_dropout(scale)

        result = scale @ v
        result = rearrange(result, "(b h) s d -> b s (h d)", h=self.num_heads)
        result = self.out_proj(result)

        return result

# %% [markdown]
# Let's check that your implementation works like `torch.nn.MultiheadAttention`

# %%
mha = torch.nn.MultiheadAttention(embed_dim=128, num_heads=16, batch_first=True)

# %%
custom_mha = CustomMultiHeadSelfAttention(embed_dim=128, num_heads=16)
custom_mha.in_proj.weight = mha.in_proj_weight
custom_mha.in_proj.bias = mha.in_proj_bias
custom_mha.out_proj.weight = mha.out_proj.weight
custom_mha.out_proj.bias = mha.out_proj.bias

# %%
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

for _ in range(100):
    a = torch.rand((1, 10, 128))
    out1 = mha(a, a, a)[0].cpu().detach().numpy()
    out2 = custom_mha(a).cpu().detach().numpy()
    assert np.allclose(out1, out2, atol=1e-6), f"{out1} {out2}"
    
print ("Congratulations! It works!")
# Out:
# Congratulations! It works!

# %% [markdown]
# ## Task 2: Step-wise learning rate with warm-up
#
# Your task is to implement class that works as `torch.optim.lr_scheduler.StepLR` but supports warm-up.
#
# First of all, examine the docstring and implementation of `StepLR` scheduler:

# %%
torch.optim.lr_scheduler.StepLR??
# Out:
# Init signature:
# torch.optim.lr_scheduler.StepLR(
#     optimizer: torch.optim.optimizer.Optimizer,
#     step_size: int,
#     gamma: float = 0.1,
#     last_epoch: int = -1,
#     verbose='deprecated',
# )
# Source:
# class StepLR(LRScheduler):
#     """Decays the learning rate of each parameter group by gamma every step_size epochs.
#
#     Notice that such decay can happen simultaneously with other changes to the learning rate
#     from outside this scheduler. When last_epoch=-1, sets initial lr as lr.
#
#     Args:
#         optimizer (Optimizer): Wrapped optimizer.
#         step_size (int): Period of learning rate decay.
#         gamma (float): Multiplicative factor of learning rate decay.
#             Default: 0.1.
#         last_epoch (int): The index of last epoch. Default: -1.
#         verbose (bool | str): If ``True``, prints a message to stdout for
#             each update. Default: ``False``.
#
#             .. deprecated:: 2.2
#                 ``verbose`` is deprecated. Please use ``get_last_lr()`` to access the
#                 learning rate.
#
#     Example:
#         >>> # xdoctest: +SKIP
#         >>> # Assuming optimizer uses lr = 0.05 for all groups
#         >>> # lr = 0.05     if epoch < 30
#         >>> # lr = 0.005    if 30 <= epoch < 60
#         >>> # lr = 0.0005   if 60 <= epoch < 90
#         >>> # ...
#         >>> scheduler = StepLR(optimizer, step_size=30, gamma=0.1)
#         >>> for epoch in range(100):
#         >>>     train(...)
#         >>>     validate(...)
#         >>>     scheduler.step()
#     """
#
#     def __init__(
#         self,
#         optimizer: Optimizer,
#         step_size: int,
#         gamma: float = 0.1,
#         last_epoch: int = -1,
#         verbose="deprecated",
#     ):  # noqa: D107
#         self.step_size = step_size
#         self.gamma = gamma
#         super().__init__(optimizer, last_epoch, verbose)
#
#     def get_lr(self):
#         """Compute the learning rate of each parameter group."""
#         _warn_get_lr_called_within_step(self)
#
#         if (self.last_epoch == 0) or (self.last_epoch % self.step_size != 0):
#             return [group["lr"] for group in self.optimizer.param_groups]
#         return [group["lr"] * self.gamma for group in self.optimizer.param_groups]
#
#     def _get_closed_form_lr(self):
#         return [
#             base_lr * self.gamma ** (self.last_epoch // self.step_size)
#             for base_lr in self.base_lrs
#         ]
# File:           ~/miniconda3/envs/sc_w8/lib/python3.10/site-packages/torch/optim/lr_scheduler.py
# Type:           type
# Subclasses:

# %% [markdown]
# Then implement `get_lr()` method. It should work as following:
# 1. If `self.last_epoch` is in `[0, self.warmup_epochs]`, scheduler is in warm-up mode and learning rates for each parameter group should lineary increase during epochs from `self.warmup_lr_init` to `self.base_lrs` (which are the original learning rates)
#
# 2. Else if `self.last_epoch - self.warmup_epochs` is not divisible by `self.step_size`, return the previous learning rates which are available through `[group['lr'] for group in self.optimizer.param_groups]`
#
# 3. Else if `self.last_epoch - self.warmup_epochs` is divisible by `self.step_size` and current learning rates multiplied by `self.gamma` are not less then `self.min_lr`, then multiply them and return new values.
#
# 4. Otherwise return the last learning rates.

# %%
import warnings


class StepLRWithWarmup(torch.optim.lr_scheduler.LRScheduler):
    def __init__(
        self,
        optimizer,
        step_size,
        gamma=0.1,
        warmup_epochs=3,
        warmup_lr_init=1e-5,
        min_lr=1e-5,
        last_epoch=-1,
        verbose=False,
    ):
        self.step_size = step_size
        self.gamma = gamma
        self.warmup_epochs = warmup_epochs
        self.warmup_lr_init = warmup_lr_init
        self.min_lr = min_lr

        super().__init__(optimizer, last_epoch, verbose)

    def get_lr(self):
        if not self._get_lr_called_within_step:
            warnings.warn(
                "To get the last learning rate computed by the scheduler, "
                "please use `get_last_lr()`.",
                UserWarning,
            )

        if self.last_epoch == 0:
            return [self.warmup_lr_init for _ in self.optimizer.param_groups]

        if self.last_epoch <= self.warmup_epochs:
            t = self.last_epoch / self.warmup_epochs
            return [
                self.warmup_lr_init + (base_lr - self.warmup_lr_init) * t
                for base_lr in self.base_lrs
            ]

        if (self.last_epoch - self.warmup_epochs) % self.step_size != 0:
            return [group["lr"] for group in self.optimizer.param_groups]

        return [
            max(self.min_lr, group["lr"] * self.gamma)
            for group in self.optimizer.param_groups
        ]

# %% [markdown]
# Let's check what you have written.

# %%
WARMUP_LR_INIT = 1e-5
WARMUP_EPOCHS = 10
STEP_SIZE = 10
GAMMA = 0.1
MIN_LR = 1e-5
OPT_LR = 1e-3

dummy_net = nn.Sequential(nn.Linear(10,10))
dummy_opt = torch.optim.Adam(dummy_net.parameters(), lr=OPT_LR)

scheduler = StepLRWithWarmup(dummy_opt, step_size=STEP_SIZE, gamma=GAMMA, 
                                      warmup_epochs=WARMUP_EPOCHS, warmup_lr_init=WARMUP_LR_INIT,
                                      min_lr=MIN_LR)

# we need to do at least one optimizer step before calling scheduler.step()
# in order to make pytorch happy
dummy_opt.step()  


learning_rates = []
for i in range(100):
    learning_rates.append(scheduler.get_last_lr())
    scheduler.step()
    
plt.plot(learning_rates)
plt.grid()
plt.title('Learning rates')
    
assert np.isclose(learning_rates[0], WARMUP_LR_INIT), \
    f"LR on the first epoch should be equal to {WARMUP_LR_INIT}, actual value {learning_rates[0]}"
assert np.isclose(learning_rates[WARMUP_EPOCHS], OPT_LR), \
    f"LR after warmup shold be equal to {OPT_LR}, actual value {learning_rates[WARMUP_EPOCHS]}"
assert np.isclose(learning_rates[WARMUP_EPOCHS+STEP_SIZE-1], OPT_LR), \
    f"LR after warmup + (STEP_SIZE-1) steps should be equal to {OPT_LR}, "\
    f"actual value {learning_rates[WARMUP_EPOCHS+STEP_SIZE-1]}"
assert np.isclose(learning_rates[WARMUP_EPOCHS+STEP_SIZE], OPT_LR*GAMMA), \
    f"LR after warmup + (STEP_SIZE) steps shold be equal to {OPT_LR*GAMMA}, " \
    f"actual value {learning_rates[WARMUP_EPOCHS+STEP_SIZE]}"

assert np.isclose(learning_rates[WARMUP_EPOCHS+STEP_SIZE*2-1], OPT_LR*GAMMA), \
    f"LR after warmup + (2*STEP_SIZE-1) steps should be equal to {OPT_LR*GAMMA}, "\
    f"actual value {learning_rates[WARMUP_EPOCHS+STEP_SIZE*2-1]}"
assert np.isclose(learning_rates[WARMUP_EPOCHS+2*STEP_SIZE], OPT_LR*GAMMA**2), \
    f"LR after warmup + (2*STEP_SIZE) steps shold be equal to {OPT_LR*GAMMA**2}, " \
    f"actual value {learning_rates[WARMUP_EPOCHS+2*STEP_SIZE]}"

assert np.isclose(learning_rates[WARMUP_EPOCHS+3*STEP_SIZE], OPT_LR*GAMMA**2), \
    f"LR after warmup + (3*STEP_SIZE) steps shold be equal to {OPT_LR*GAMMA**2}, " \
    f"actual value {learning_rates[WARMUP_EPOCHS+3*STEP_SIZE]}"

for i in range(WARMUP_EPOCHS):
    expected_val = WARMUP_LR_INIT + i*(OPT_LR-WARMUP_LR_INIT) / WARMUP_EPOCHS
    actual_val = learning_rates[i]
    assert np.isclose(actual_val, expected_val), \
        f"LR should linary increase from {WARMUP_LR_INIT} to {OPT_LR} during warmup."\
        f"Expected: {expected_val}, actual: {actual_val}, iteration={i}"
assert all(elem[0] >= MIN_LR for elem in learning_rates)
print("All asserts were passed!")
# Out:
# All asserts were passed!

# %% [markdown]
# ## Task 3. Compact Convolutional Transformer
#
# During seminar you learned the main components of vision transformer: Tokenizer, Transformer encoder, position embeddings. At this point, it's expected that you have solved the ipython notebook from the seminar. If you didn't, then you know what to do before starting the current task)

# %% [markdown]
# Your task is to implement Compact Convolutional Transformer (CCT). It has two main changes comparing to the original ViT that was implemented during seminar. The first one is in tokenizer. Authors of CCT suggested to apply the first convolution with stride=1 allowing transformer to work with input patches that overlaps with each other. Since simple removing of stride increases the spatial resolution of the input tensor, we use MaxPool2d with desired stride in order to reduce the number of tokens.

# %%
class TokenizerCCT(nn.Module):
    def __init__(
        self,
        kernel_size=3,
        stride=1,
        padding=1,
        pooling_kernel_size=3,
        pooling_stride=2,
        pooling_padding=1,
        n_input_channels=3,
        n_output_channels=64,
    ):
        super().__init__()
        self.tokenizer_layers = nn.Sequential(
            # YOUR CODE
            # it should implement the following sequence of layers:
            # Conv2d(n_input_channels, n_output_channels, kernel_size, stride, padding, bias=False) +
            #   + ReLU +
            #   + MaxPool(pooling_kernel_size, pooling_stride, pooling_padding)
            nn.Conv2d(
                n_input_channels,
                n_output_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            nn.ReLU(),
            nn.MaxPool2d(pooling_kernel_size, pooling_stride, pooling_padding),
        )

        self.flattener = nn.Flatten(2, 3)  # flat h,w dims into token dim

    def forward(self, x):
        y = self.tokenizer_layers(x)
        y = self.flattener(y)
        y = y.transpose(-2, -1)  # swap token dim and embedding dim
        return y

# %% [markdown]
# The second change is that CCT uses learnable pooling instead of class token for global features extraction. Its formula is similar to attention formula:
# $$y = \text{softmax}(WX^T+b) * X$$
# where $X$ - layer input - matrix of shape [batch_size, n_tokens, n_embedding], $W$, $b$ - learnable parameters, that transform each token embedding vector to 1 element (in fact it's just a linear layer with output_dim=1).

# %%
class SeqPooling(nn.Module):
    def __init__(self, embedding_dim):
        super().__init__()
        self.attention_pool = nn.Linear(embedding_dim, 1)

    def forward(self, x):
        # YOUR CODE
        # 1. apply self.attention_pool to x
        w = self.attention_pool(x)
        # 2. take softmax over the first dim (token dim)
        w = F.softmax(w, dim=1)
        # 3. transpose two last dims of w to make its shape be equal to [N, 1, n_tokens]
        w = w.transpose(1, 2)

        # 4. call torch.matmul from 'w' and input tensor 'x'
        y = w @ x

        # 5. now 'y' shape is [N, 1, embedding_dim]. Squeeze the second dim
        y = y.squeeze(1)

        return y

# %% [markdown]
# The following three modules were implemented by you during seminar, so you can just copy-paste their implementations.

# %%
def create_mlp(embedding_dim, mlp_size, dropout_rate):
    return nn.Sequential(
        # YOUR CODE: Linear + GELU + Dropout + Linear + Dropout
        nn.Linear(embedding_dim, mlp_size),
        nn.GELU(),
        nn.Dropout(dropout_rate),
        nn.Linear(mlp_size, embedding_dim),
        nn.Dropout(dropout_rate),
    )

# %%
class DropPath(nn.Module):
    def __init__(self, drop_prob=None):
        super(DropPath, self).__init__()
        self.drop_prob = drop_prob

    def forward(self, x):
        if self.drop_prob == 0.0 or not self.training:
            return x
        keep_prob = 1 - self.drop_prob
        shape = (x.shape[0],) + (1,) * (
            x.ndim - 1
        )  # work with diff dim tensors, not just 2D ConvNets
        # YOUR CODE: generate random tensor, binarize it, cast to x.dtype, multiply x by the mask,
        # devide the result on keep_prob
        random_tensor = torch.rand(shape, device=x.device)
        mask = random_tensor <= keep_prob
        output = (x * mask) / keep_prob
        return output

# it is also highly recommended to write some simple test to ensure,
# that this layer indeed nullifies input with probability `drop_prob`

# %%
class TransformerEncoder(nn.Module):
    def __init__(
        self,
        embedding_dim,
        num_heads,
        mlp_size,
        dropout=0.1,
        attention_dropout=0.1,
        drop_path_rate=0.1,
    ):
        super().__init__()
        # YOUR CODE
        self.attention_pre_norm = nn.LayerNorm(embedding_dim)
        self.attention = torch.nn.MultiheadAttention(
            embedding_dim, num_heads, dropout=attention_dropout, batch_first=True
        )  # Do not forget to set `batch_first` parameter
        self.attention_output_dropout = nn.Dropout(dropout)

        self.mlp_pre_norm = nn.LayerNorm(embedding_dim)
        self.mlp = create_mlp(embedding_dim, mlp_size, dropout)
        self.drop_path = (
            DropPath(drop_path_rate) if drop_path_rate > 0 else nn.Identity()
        )

    def forward(self, x):
        # first block
        y = self.attention_pre_norm(x)
        attention = self.attention(y, y, y)[0]
        attention = self.attention_output_dropout(attention)
        x = x + self.drop_path(attention)  # Residual connection

        # second block
        y = self.mlp_pre_norm(x)
        y = self.mlp(y)
        x = x + self.drop_path(y)  # Residual connection
        return x

# %% [markdown]
# The final class for the CCT. It looks the same as `VisionTransformer` class in seminar notebook, except the custom tokenizer and pooling. Here we implement a simple version of CCT, whose Tokenizer consist of one convolution of 3x3.

# %%
class CompactConvTransformer3x1(nn.Module):
    def __init__(self,
                 input_height, input_width,
                 n_tokens,
                 n_input_channels,
                 embedding_dim,
                 num_layers,
                 num_heads=4,
                 num_classes=10,
                 mlp_ratio=2,
                 dropout=0.1,
                 attention_dropout=0.1,
                 stochastic_depth=0.1):
        super().__init__()
        
        # 1. Tokenizer
        pooling_stride = 2
        self.tokenizer = TokenizerCCT(kernel_size=3, stride=1, padding=1, 
                                      pooling_kernel_size=3, pooling_stride=pooling_stride, pooling_padding=1,
                                      n_output_channels=embedding_dim)
        n_tokens = input_height // pooling_stride
        
        # 2. Positional embeddings
        self.positional_embeddings = torch.nn.Parameter(
            torch.empty((1, n_tokens*n_tokens, embedding_dim)), requires_grad=True)
        torch.nn.init.trunc_normal_(self.positional_embeddings, std=0.2)
        
        # 3. TransformerEncoder with DropPath
        mlp_size = int(embedding_dim * mlp_ratio)
        layers_drop_path_rate = [x.item() for x in torch.linspace(0, stochastic_depth, num_layers)]
        self.blocks = nn.Sequential(*[
            TransformerEncoder(
                embedding_dim, num_heads, mlp_size, 
                dropout=dropout, attention_dropout=attention_dropout,
                drop_path_rate=layers_drop_path_rate[i]) 
            for i in range(num_layers)])
        
        # 4. normalization before pooling
        self.norm = nn.LayerNorm(embedding_dim)
        
        # 5. sequence pooling
        self.pool = SeqPooling(embedding_dim)

        # 6. layer for the final prediction
        self.fc = nn.Linear(embedding_dim, num_classes)
        
    def forward(self, x):
        # YOUR CODE
        # 1. apply tokenizer to x
        patch_embeddings = self.tokenizer(x)
        
        # 2. add position embeddings
        x = patch_embeddings + self.positional_embeddings

        # 3. apply transformer encoder blocks
        for block in self.blocks:
            x = block(x)
            
        # 4. apply self.norm
        x = self.norm(x)
        
        # 5. apply sequence pooling
        x = self.pool(x)
        
        # 6. final prediction
        x = self.fc(x)
        return x

# %% [markdown]
# ## Final training
#
# If everything was implemented correctly, the following code will give you a model with > 85.5% accuracy (in fact it should be ~87.5%). If you see a smaller number, check your implementation of modules above.

# %%
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

model = CompactConvTransformer3x1(input_height=32, input_width=32, n_tokens=16, n_input_channels=3, 
                                  embedding_dim=128, num_layers=4, num_heads=4, num_classes=10, mlp_ratio=2)
model = model.to(device)
opt = torch.optim.Adam(model.parameters(), weight_decay=1e-4)
scheduler = StepLRWithWarmup(opt, 40, gamma=0.3, warmup_epochs=10)
# Out:
# /home/o-verbin/miniconda3/envs/sc_w8/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
import time
from tqdm.auto import tqdm
num_epochs = 120 # total amount of full passes over training data

for epoch in tqdm(range(num_epochs)):
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    train_loss = []
    val_accuracy = []
    
    for X_batch, y_batch in train_batch_gen:
        opt.zero_grad()
        # train on batch
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)
        
        logits = model(X_batch)
        loss = compute_loss(logits, y_batch)
        loss.backward()
        opt.step()
        train_loss.append(loss.data.numpy())
    print(scheduler.get_last_lr())
    scheduler.step()
        
    # And a full pass over the validation data:
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in val_batch_gen:
        X_batch = X_batch.to(device)
        y_batch = y_batch.numpy()
        logits = model(X_batch).cpu()
        y_pred = logits.max(1)[1].data.numpy()
        val_accuracy.append(np.mean(y_batch == y_pred))

    
    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss)))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy) * 100))
# Out:
#   0%|          | 0/120 [00:00<?, ?it/s]
# [1e-05]
# Epoch 1 of 120 took 30.078s
#   training loss (in-iteration): 	2.059802
#   validation accuracy: 			32.58 %
# [0.000109]
# Epoch 2 of 120 took 27.826s
#   training loss (in-iteration): 	1.713295
#   validation accuracy: 			46.88 %
# [0.00020800000000000001]
# Epoch 3 of 120 took 27.925s
#   training loss (in-iteration): 	1.490849
#   validation accuracy: 			55.18 %
# [0.00030700000000000004]
# Epoch 4 of 120 took 27.785s
#   training loss (in-iteration): 	1.324015
#   validation accuracy: 			58.49 %
# [0.00040600000000000006]
# Epoch 5 of 120 took 28.153s
#   training loss (in-iteration): 	1.228444
#   validation accuracy: 			63.80 %
# [0.000505]
# Epoch 6 of 120 took 28.107s
#   training loss (in-iteration): 	1.148084
#   validation accuracy: 			63.85 %
# [0.000604]
# Epoch 7 of 120 took 28.221s
#   training loss (in-iteration): 	1.092154
#   validation accuracy: 			63.48 %
# [0.000703]
# Epoch 8 of 120 took 28.389s
#   training loss (in-iteration): 	1.048870
#   validation accuracy: 			68.43 %
# [0.0008020000000000001]
# Epoch 9 of 120 took 28.910s
#   training loss (in-iteration): 	1.005855
#   validation accuracy: 			68.30 %
# [0.000901]
# Epoch 10 of 120 took 28.782s
#   training loss (in-iteration): 	0.983571
#   validation accuracy: 			69.93 %
# [0.001]
# Epoch 11 of 120 took 28.970s
#   training loss (in-iteration): 	0.963062
#   validation accuracy: 			69.25 %
# [0.001]
# Epoch 12 of 120 took 28.791s
#   training loss (in-iteration): 	0.931861
#   validation accuracy: 			69.67 %
# [0.001]
# Epoch 13 of 120 took 29.250s
#   training loss (in-iteration): 	0.899487
#   validation accuracy: 			72.74 %
# [0.001]
# Epoch 14 of 120 took 31.875s
#   training loss (in-iteration): 	0.867750
#   validation accuracy: 			70.50 %
# [0.001]
# Epoch 15 of 120 took 33.013s
#   training loss (in-iteration): 	0.844550
#   validation accuracy: 			70.13 %
# [0.001]
# Epoch 16 of 120 took 35.277s
#   training loss (in-iteration): 	0.826790
#   validation accuracy: 			73.75 %
# [0.001]
# Epoch 17 of 120 took 37.685s
#   training loss (in-iteration): 	0.803031
#   validation accuracy: 			75.22 %
# [0.001]
# Epoch 18 of 120 took 31.130s
#   training loss (in-iteration): 	0.777598
#   validation accuracy: 			75.47 %
# [0.001]
# Epoch 19 of 120 took 31.776s
#   training loss (in-iteration): 	0.763355
#   validation accuracy: 			75.96 %
# [0.001]
# Epoch 20 of 120 took 31.965s
#   training loss (in-iteration): 	0.747529
#   validation accuracy: 			76.64 %
# [0.001]
# Epoch 21 of 120 took 29.739s
#   training loss (in-iteration): 	0.732235
#   validation accuracy: 			77.50 %
# [0.001]
# Epoch 22 of 120 took 30.264s
#   training loss (in-iteration): 	0.721617
#   validation accuracy: 			74.83 %
# [0.001]
# Epoch 23 of 120 took 31.591s
#   training loss (in-iteration): 	0.706288
#   validation accuracy: 			78.27 %
# [0.001]
# Epoch 24 of 120 took 31.856s
#   training loss (in-iteration): 	0.701751
#   validation accuracy: 			78.81 %
# [0.001]
# Epoch 25 of 120 took 29.974s
#   training loss (in-iteration): 	0.685626
#   validation accuracy: 			79.19 %
# [0.001]
# Epoch 26 of 120 took 29.813s
#   training loss (in-iteration): 	0.673957
#   validation accuracy: 			78.42 %
# [0.001]
# Epoch 27 of 120 took 30.772s
#   training loss (in-iteration): 	0.670229
#   validation accuracy: 			76.69 %
# [0.001]
# Epoch 28 of 120 took 31.701s
#   training loss (in-iteration): 	0.657702
#   validation accuracy: 			79.00 %
# [0.001]
# Epoch 29 of 120 took 31.517s
#   training loss (in-iteration): 	0.643826
#   validation accuracy: 			78.18 %
# [0.001]
# Epoch 30 of 120 took 32.466s
#   training loss (in-iteration): 	0.642524
#   validation accuracy: 			78.86 %
# [0.001]
# Epoch 31 of 120 took 31.744s
#   training loss (in-iteration): 	0.632163
#   validation accuracy: 			80.37 %
# [0.001]
# Epoch 32 of 120 took 31.778s
#   training loss (in-iteration): 	0.622192
#   validation accuracy: 			79.29 %
# [0.001]
# Epoch 33 of 120 took 31.960s
#   training loss (in-iteration): 	0.614337
#   validation accuracy: 			79.75 %
# [0.001]
# Epoch 34 of 120 took 31.273s
#   training loss (in-iteration): 	0.618803
#   validation accuracy: 			81.30 %
# [0.001]
# Epoch 35 of 120 took 31.466s
#   training loss (in-iteration): 	0.602254
#   validation accuracy: 			78.59 %
# [0.001]
# Epoch 36 of 120 took 30.011s
#   training loss (in-iteration): 	0.597176
#   validation accuracy: 			79.72 %
# [0.001]
# Epoch 37 of 120 took 30.305s
#   training loss (in-iteration): 	0.591845
#   validation accuracy: 			80.43 %
# [0.001]
# Epoch 38 of 120 took 32.255s
#   training loss (in-iteration): 	0.588167
#   validation accuracy: 			79.96 %
# [0.001]
# Epoch 39 of 120 took 33.157s
#   training loss (in-iteration): 	0.580178
#   validation accuracy: 			81.48 %
# [0.001]
# Epoch 40 of 120 took 32.629s
#   training loss (in-iteration): 	0.573265
#   validation accuracy: 			80.02 %
# [0.001]
# Epoch 41 of 120 took 31.922s
#   training loss (in-iteration): 	0.570742
#   validation accuracy: 			81.26 %
# [0.001]
# Epoch 42 of 120 took 32.995s
#   training loss (in-iteration): 	0.560217
#   validation accuracy: 			82.65 %
# [0.001]
# Epoch 43 of 120 took 31.529s
#   training loss (in-iteration): 	0.555173
#   validation accuracy: 			79.79 %
# [0.001]
# Epoch 44 of 120 took 32.844s
#   training loss (in-iteration): 	0.551705
#   validation accuracy: 			81.03 %
# [0.001]
# Epoch 45 of 120 took 32.801s
#   training loss (in-iteration): 	0.546610
#   validation accuracy: 			81.26 %
# [0.001]
# Epoch 46 of 120 took 33.738s
#   training loss (in-iteration): 	0.544633
#   validation accuracy: 			82.49 %
# [0.001]
# Epoch 47 of 120 took 33.515s
#   training loss (in-iteration): 	0.538807
#   validation accuracy: 			81.81 %
# [0.001]
# Epoch 48 of 120 took 32.451s
#   training loss (in-iteration): 	0.534811
#   validation accuracy: 			82.47 %
# [0.001]
# Epoch 49 of 120 took 33.360s
#   training loss (in-iteration): 	0.533434
#   validation accuracy: 			83.02 %
# [0.001]
# Epoch 50 of 120 took 32.132s
#   training loss (in-iteration): 	0.525182
#   validation accuracy: 			81.74 %
# [0.0003]
# Epoch 51 of 120 took 32.218s
#   training loss (in-iteration): 	0.415000
#   validation accuracy: 			85.12 %
# [0.0003]
# Epoch 52 of 120 took 33.017s
#   training loss (in-iteration): 	0.399031
#   validation accuracy: 			85.75 %
# [0.0003]
# Epoch 53 of 120 took 32.418s
#   training loss (in-iteration): 	0.386718
#   validation accuracy: 			85.30 %
# [0.0003]
# Epoch 54 of 120 took 32.623s
#   training loss (in-iteration): 	0.374248
#   validation accuracy: 			86.00 %
# [0.0003]
# Epoch 55 of 120 took 32.606s
#   training loss (in-iteration): 	0.366425
#   validation accuracy: 			86.11 %
# [0.0003]
# Epoch 56 of 120 took 33.925s
#   training loss (in-iteration): 	0.365985
#   validation accuracy: 			85.65 %
# [0.0003]
# Epoch 57 of 120 took 32.297s
#   training loss (in-iteration): 	0.361192
#   validation accuracy: 			85.67 %
# [0.0003]
# Epoch 58 of 120 took 33.711s
#   training loss (in-iteration): 	0.357899
#   validation accuracy: 			86.06 %
# [0.0003]
# Epoch 59 of 120 took 33.657s
#   training loss (in-iteration): 	0.352059
#   validation accuracy: 			85.99 %
# [0.0003]
# Epoch 60 of 120 took 33.215s
#   training loss (in-iteration): 	0.347319
#   validation accuracy: 			86.06 %
# [0.0003]
# Epoch 61 of 120 took 33.657s
#   training loss (in-iteration): 	0.349038
#   validation accuracy: 			85.71 %
# [0.0003]
# Epoch 62 of 120 took 34.922s
#   training loss (in-iteration): 	0.339331
#   validation accuracy: 			86.17 %
# [0.0003]
# Epoch 63 of 120 took 32.512s
#   training loss (in-iteration): 	0.336184
#   validation accuracy: 			85.92 %
# [0.0003]
# Epoch 64 of 120 took 35.594s
#   training loss (in-iteration): 	0.333457
#   validation accuracy: 			85.80 %
# [0.0003]
# Epoch 65 of 120 took 34.722s
#   training loss (in-iteration): 	0.330125
#   validation accuracy: 			85.60 %
# [0.0003]
# Epoch 66 of 120 took 34.043s
#   training loss (in-iteration): 	0.334490
#   validation accuracy: 			86.12 %
# [0.0003]
# Epoch 67 of 120 took 34.073s
#   training loss (in-iteration): 	0.328254
#   validation accuracy: 			86.09 %
# [0.0003]
# Epoch 68 of 120 took 33.850s
#   training loss (in-iteration): 	0.323722
#   validation accuracy: 			85.96 %
# [0.0003]
# Epoch 69 of 120 took 33.906s
#   training loss (in-iteration): 	0.319036
#   validation accuracy: 			86.16 %
# [0.0003]
# Epoch 70 of 120 took 32.962s
#   training loss (in-iteration): 	0.320440
#   validation accuracy: 			86.42 %
# [0.0003]
# Epoch 71 of 120 took 37.134s
#   training loss (in-iteration): 	0.320998
#   validation accuracy: 			86.08 %
# [0.0003]
# Epoch 72 of 120 took 36.986s
#   training loss (in-iteration): 	0.316902
#   validation accuracy: 			85.76 %
# [0.0003]
# Epoch 73 of 120 took 37.464s
#   training loss (in-iteration): 	0.310051
#   validation accuracy: 			86.24 %
# [0.0003]
# Epoch 74 of 120 took 33.995s
#   training loss (in-iteration): 	0.313247
#   validation accuracy: 			86.72 %
# [0.0003]
# Epoch 75 of 120 took 32.856s
#   training loss (in-iteration): 	0.305525
#   validation accuracy: 			86.04 %
# [0.0003]
# Epoch 76 of 120 took 32.029s
#   training loss (in-iteration): 	0.308982
#   validation accuracy: 			85.84 %
# [0.0003]
# Epoch 77 of 120 took 32.269s
#   training loss (in-iteration): 	0.305197
#   validation accuracy: 			85.85 %
# [0.0003]
# Epoch 78 of 120 took 33.994s
#   training loss (in-iteration): 	0.303873
#   validation accuracy: 			86.06 %
# [0.0003]
# Epoch 79 of 120 took 33.278s
#   training loss (in-iteration): 	0.300826
#   validation accuracy: 			86.38 %
# [0.0003]
# Epoch 80 of 120 took 33.501s
#   training loss (in-iteration): 	0.297705
#   validation accuracy: 			86.08 %
# [0.0003]
# Epoch 81 of 120 took 34.117s
#   training loss (in-iteration): 	0.297487
#   validation accuracy: 			86.27 %
# [0.0003]
# Epoch 82 of 120 took 36.526s
#   training loss (in-iteration): 	0.294096
#   validation accuracy: 			85.80 %
# [0.0003]
# Epoch 83 of 120 took 36.848s
#   training loss (in-iteration): 	0.295702
#   validation accuracy: 			85.90 %
# [0.0003]
# Epoch 84 of 120 took 34.729s
#   training loss (in-iteration): 	0.294712
#   validation accuracy: 			86.45 %
# [0.0003]
# Epoch 85 of 120 took 34.363s
#   training loss (in-iteration): 	0.288877
#   validation accuracy: 			86.38 %
# [0.0003]
# Epoch 86 of 120 took 34.134s
#   training loss (in-iteration): 	0.285475
#   validation accuracy: 			85.93 %
# [0.0003]
# Epoch 87 of 120 took 34.172s
#   training loss (in-iteration): 	0.289219
#   validation accuracy: 			86.07 %
# [0.0003]
# Epoch 88 of 120 took 33.081s
#   training loss (in-iteration): 	0.286934
#   validation accuracy: 			85.90 %
# [0.0003]
# Epoch 89 of 120 took 33.691s
#   training loss (in-iteration): 	0.282299
#   validation accuracy: 			85.69 %
# [0.0003]
# Epoch 90 of 120 took 36.624s
#   training loss (in-iteration): 	0.279053
#   validation accuracy: 			85.79 %
# [8.999999999999999e-05]
# Epoch 91 of 120 took 32.430s
#   training loss (in-iteration): 	0.234023
#   validation accuracy: 			86.98 %
# [8.999999999999999e-05]
# Epoch 92 of 120 took 37.794s
#   training loss (in-iteration): 	0.224564
#   validation accuracy: 			86.91 %
# [8.999999999999999e-05]
# Epoch 93 of 120 took 35.405s
#   training loss (in-iteration): 	0.220938
#   validation accuracy: 			87.17 %
# [8.999999999999999e-05]
# Epoch 94 of 120 took 33.909s
#   training loss (in-iteration): 	0.218415
#   validation accuracy: 			87.13 %
# [8.999999999999999e-05]
# Epoch 95 of 120 took 32.467s
#   training loss (in-iteration): 	0.215278
#   validation accuracy: 			87.16 %
# [8.999999999999999e-05]
# Epoch 96 of 120 took 32.832s
#   training loss (in-iteration): 	0.212090
#   validation accuracy: 			86.92 %
# [8.999999999999999e-05]
# Epoch 97 of 120 took 33.694s
#   training loss (in-iteration): 	0.213278
#   validation accuracy: 			87.16 %
# [8.999999999999999e-05]
# Epoch 98 of 120 took 31.355s
#   training loss (in-iteration): 	0.204987
#   validation accuracy: 			87.06 %
# [8.999999999999999e-05]
# Epoch 99 of 120 took 30.811s
#   training loss (in-iteration): 	0.207456
#   validation accuracy: 			87.24 %
# [8.999999999999999e-05]
# Epoch 100 of 120 took 30.588s
#   training loss (in-iteration): 	0.207448
#   validation accuracy: 			87.10 %
# [8.999999999999999e-05]
# Epoch 101 of 120 took 32.258s
#   training loss (in-iteration): 	0.201531
#   validation accuracy: 			86.75 %
# [8.999999999999999e-05]
# Epoch 102 of 120 took 33.440s
#   training loss (in-iteration): 	0.201480
#   validation accuracy: 			86.93 %
# [8.999999999999999e-05]
# Epoch 103 of 120 took 30.209s
#   training loss (in-iteration): 	0.203156
#   validation accuracy: 			87.14 %
# [8.999999999999999e-05]
# Epoch 104 of 120 took 32.103s
#   training loss (in-iteration): 	0.200999
#   validation accuracy: 			87.11 %
# [8.999999999999999e-05]
# Epoch 105 of 120 took 30.946s
#   training loss (in-iteration): 	0.201379
#   validation accuracy: 			87.31 %
# [8.999999999999999e-05]
# Epoch 106 of 120 took 31.932s
#   training loss (in-iteration): 	0.197371
#   validation accuracy: 			87.30 %
# [8.999999999999999e-05]
# Epoch 107 of 120 took 30.265s
#   training loss (in-iteration): 	0.199474
#   validation accuracy: 			87.14 %
# [8.999999999999999e-05]
# Epoch 108 of 120 took 30.740s
#   training loss (in-iteration): 	0.199699
#   validation accuracy: 			86.89 %
# [8.999999999999999e-05]
# Epoch 109 of 120 took 30.561s
#   training loss (in-iteration): 	0.194778
#   validation accuracy: 			87.10 %
# [8.999999999999999e-05]
# Epoch 110 of 120 took 30.901s
#   training loss (in-iteration): 	0.195231
#   validation accuracy: 			87.04 %
# [8.999999999999999e-05]
# Epoch 111 of 120 took 30.023s
#   training loss (in-iteration): 	0.193913
#   validation accuracy: 			86.78 %
# [8.999999999999999e-05]
# Epoch 112 of 120 took 29.802s
#   training loss (in-iteration): 	0.192896
#   validation accuracy: 			87.02 %
# [8.999999999999999e-05]
# Epoch 113 of 120 took 29.827s
#   training loss (in-iteration): 	0.194364
#   validation accuracy: 			87.05 %
# [8.999999999999999e-05]
# Epoch 114 of 120 took 30.397s
#   training loss (in-iteration): 	0.188728
#   validation accuracy: 			86.82 %
# [8.999999999999999e-05]
# Epoch 115 of 120 took 30.547s
#   training loss (in-iteration): 	0.191991
#   validation accuracy: 			87.04 %
# [8.999999999999999e-05]
# Epoch 116 of 120 took 30.001s
#   training loss (in-iteration): 	0.189922
#   validation accuracy: 			87.08 %
# [8.999999999999999e-05]
# Epoch 117 of 120 took 30.488s
#   training loss (in-iteration): 	0.187814
#   validation accuracy: 			86.97 %
# [8.999999999999999e-05]
# Epoch 118 of 120 took 29.206s
#   training loss (in-iteration): 	0.186416
#   validation accuracy: 			87.18 %
# [8.999999999999999e-05]
# Epoch 119 of 120 took 29.177s
#   training loss (in-iteration): 	0.185485
#   validation accuracy: 			87.44 %
# [8.999999999999999e-05]
# Epoch 120 of 120 took 29.724s
#   training loss (in-iteration): 	0.186909
#   validation accuracy: 			87.18 %
